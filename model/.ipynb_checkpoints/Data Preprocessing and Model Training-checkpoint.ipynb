# %% [markdown]
# # Hollywood Actors Image Classification

# %% [markdown]
# ### Problem Statement
# - #### The main aim of this project is to classify images of the Hollywood Actors scrapped from google using opencv library and Machine Learning Algorithms

# %% [markdown]
# #### Importing Dependencies

# %%
! pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\guddu\appdata\local\programs\python\python310\lib\site-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\guddu\appdata\local\programs\python\python310\lib\site-packages (from opencv-python) (1.25.2)
# WARNING: Ignoring invalid distribution -illow (c:\users\guddu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\guddu\appdata\local\programs\python\python310\lib\site-packages)

# %%
! pip install PyWavelets
# Out:
# Requirement already satisfied: PyWavelets in c:\users\guddu\appdata\local\programs\python\python310\lib\site-packages (1.4.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\guddu\appdata\local\programs\python\python310\lib\site-packages (from PyWavelets) (1.25.2)
# WARNING: Ignoring invalid distribution -illow (c:\users\guddu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\guddu\appdata\local\programs\python\python310\lib\site-packages)

# %%
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Preprocessing: Detect face and eyes

# %% [markdown]
# #### When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.

# %%
img = cv2.imread('test_Images/brad_2.jpg')
img.shape
# Out:
# (2048, 1363, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (2048, 1363)

# %%
gray
# Out:
# array([[ 98,  99,  98, ..., 184, 184, 184],
#        [ 98,  99,  99, ..., 184, 184, 184],
#        [ 98,  99,  99, ..., 184, 184, 184],
#        ...,
#        [  0,   0,   0, ...,   6,   5,   5],
#        [  0,   0,   0, ...,   3,   2,   2],
#        [  0,   0,   0, ...,   2,   2,   1]], dtype=uint8)

# %%
plt.imshow(gray,cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces=face_cascade.detectMultiScale(gray,1.3,5)
faces
# Out:
# array([[382, 323, 673, 673]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (382, 323, 673, 673)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

plt.figure()
plt.imshow(face_img,cmap='gray')
plt.show()

# %% [markdown]
# ## Preprocessing: Crop the facial region of the image

# %%
plt.imshow(roi_gray,cmap='gray')

# %%
plt.imshow(roi_color,cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (673, 673, 3)

# %% [markdown]
# ## Preprocessing: Use wavelet transform as a feature for traning our model

# %% [markdown]
# ### WAvelet Transform

# %%
import pywt

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)
    #print(coeffs)
    
    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# ##### You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# ## Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h,x:x+w]
        roi_color = img[y:y+h,x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes)>=2:
            return roi_color

# %%
original_Image = cv2.imread('test_Images/brad_45.jpg')
plt.imshow(original_Image,cmap='gray')

# %%
cropped_Image = get_cropped_image_if_2_eyes('test_Images/brad_45.jpg')
plt.imshow(cropped_Image)

# %% [markdown]
# #### In below image face is not very clear and it doesn't have two eyes clearly visible

# %%
original_Image_obstructed = cv2.imread('test_Images/brad_67.jpg')
plt.imshow(original_Image_obstructed,cmap='gray')

# %%
cropped_Image_no_2_eyes = get_cropped_image_if_2_eyes('test_Images/brad_67.jpg')
cropped_Image_no_2_eyes # returns nothing as the eyes are not visible

# %% [markdown]
# ##### Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training

# %%
## Creating a path inside dataset directory for storing cropped images
path_to_data = "./dataset/"
path_to_cropped_data= "./dataset/cropped/"

# %%
# Creating a python list for all the folders in the dataset directory
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/brad_pitt',
#  './dataset/chris_hemsworth',
#  './dataset/dwayane_johnson',
#  './dataset/leonardo_dicaprio',
#  './dataset/will_smith']

# %% [markdown]
# ##### Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code

# %%
import shutil
if os.path.exists(path_to_cropped_data):
    shutil.rmtree(path_to_cropped_data)

os.mkdir(path_to_cropped_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict ={}

# iterate through all the paths and extract folders
for img_dir in img_dirs:
    count=1
    celebrity_name = img_dir.split('/')[-1]
    print (celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = [] # disctionary with each folder name
    
    # iterate through all the folders and then images inside the folders
    for entry in os.scandir(img_dir):
        # iterate through each images
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cropped_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)

            # Creating the name and path for each returned cropped images in each folder
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + '/' + cropped_file_name

            # Assigning the returned cropped image to its corresponding path
            cv2.imwrite(cropped_file_path,roi_color)

            # Assigning all the filepath in a dictionary
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count+=1
# Out:
# brad_pitt
# Generating cropped images in folder:  ./dataset/cropped/brad_pitt
# chris_hemsworth
# Generating cropped images in folder:  ./dataset/cropped/chris_hemsworth
# dwayane_johnson
# Generating cropped images in folder:  ./dataset/cropped/dwayane_johnson
# leonardo_dicaprio
# Generating cropped images in folder:  ./dataset/cropped/leonardo_dicaprio
# will_smith
# Generating cropped images in folder:  ./dataset/cropped/will_smith

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'brad_pitt': ['./dataset/cropped/brad_pitt\\brad_pitt1.png',
#   './dataset/cropped/brad_pitt\\brad_pitt10.png',
#   './dataset/cropped/brad_pitt\\brad_pitt11.png',
#   './dataset/cropped/brad_pitt\\brad_pitt12.png',
#   './dataset/cropped/brad_pitt\\brad_pitt13.png',
#   './dataset/cropped/brad_pitt\\brad_pitt14.png',
#   './dataset/cropped/brad_pitt\\brad_pitt15.png',
#   './dataset/cropped/brad_pitt\\brad_pitt16.png',
#   './dataset/cropped/brad_pitt\\brad_pitt17.png',
#   './dataset/cropped/brad_pitt\\brad_pitt18.png',
#   './dataset/cropped/brad_pitt\\brad_pitt19.png',
#   './dataset/cropped/brad_pitt\\brad_pitt2.png',
#   './dataset/cropped/brad_pitt\\brad_pitt20.png',
#   './dataset/cropped/brad_pitt\\brad_pitt21.png',
#   './dataset/cropped/brad_pitt\\brad_pitt22.png',
#   './dataset/cropped/brad_pitt\\brad_pitt23.png',
#   './dataset/cropped/brad_pitt\\brad_pitt24.png',
#   './dataset/cropped/brad_pitt\\brad_pitt25.png',
#   './dataset/cropped/brad_pitt\\brad_pitt26.png',
#   './dataset/cropped/brad_pitt\\brad_pitt27.png',
#   './dataset/cropped/brad_pitt\\brad_pitt29.png',
#   './dataset/cropped/brad_pitt\\brad_pitt3.png',
#   './dataset/cropped/brad_pitt\\brad_pitt31.png',
#   './dataset/cropped/brad_pitt\\brad_pitt32.png',
#   './dataset/cropped/brad_pitt\\brad_pitt33.png',
#   './dataset/cropped/brad_pitt\\brad_pitt34.png',
#   './dataset/cropped/brad_pitt\\brad_pitt35.png',
#   './dataset/cropped/brad_pitt\\brad_pitt37.png',
#   './dataset/cropped/brad_pitt\\brad_pitt38.png',
#   './dataset/cropped/brad_pitt\\brad_pitt39.png',
#   './dataset/cropped/brad_pitt\\brad_pitt4.png',
#   './dataset/cropped/brad_pitt\\brad_pitt40.png',
#   './dataset/cropped/brad_pitt\\brad_pitt41.png',
#   './dataset/cropped/brad_pitt\\brad_pitt43.png',
#   './dataset/cropped/brad_pitt\\brad_pitt6.png',
#   './dataset/cropped/brad_pitt\\brad_pitt7.png',
#   './dataset/cropped/brad_pitt\\brad_pitt8.png',
#   './dataset/cropped/brad_pitt\\brad_pitt9.png'],
#  'chris_hemsworth': ['./dataset/cropped/chris_hemsworth\\chris_hemsworth1.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth10.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth12.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth13.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth14.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth15.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth16.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth17.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth18.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth2.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth20.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth21.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth22.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth23.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth24.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth26.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth27.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth28.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth29.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth3.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth32.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth33.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth35.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth36.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth37.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth38.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth39.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth4.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth6.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth7.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth8.png',
#   './dataset/cropped/chris_hemsworth\\chris_hemsworth9.png'],
#  'dwayane_johnson': ['./dataset/cropped/dwayane_johnson\\dwayane_johnson1.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson10.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson11.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson12.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson13.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson14.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson15.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson16.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson17.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson2.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson20.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson21.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson22.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson23.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson24.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson25.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson26.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson27.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson28.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson29.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson3.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson30.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson31.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson32.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson33.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson34.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson35.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson4.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson5.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson6.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson7.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson8.png',
#   './dataset/cropped/dwayane_johnson\\dwayane_johnson9.png'],
#  'leonardo_dicaprio': ['./dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio1.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio10.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio12.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio13.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio14.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio15.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio16.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio17.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio18.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio19.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio2.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio20.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio21.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio22.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio23.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio24.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio25.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio26.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio27.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio28.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio29.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio3.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio30.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio31.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio32.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio34.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio35.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio36.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio37.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio38.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio39.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio40.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio42.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio43.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio44.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio45.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio46.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio6.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio7.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio8.png',
#   './dataset/cropped/leonardo_dicaprio\\leonardo_dicaprio9.png'],
#  'will_smith': ['./dataset/cropped/will_smith\\will_smith1.png',
#   './dataset/cropped/will_smith\\will_smith10.png',
#   './dataset/cropped/will_smith\\will_smith11.png',
#   './dataset/cropped/will_smith\\will_smith12.png',
#   './dataset/cropped/will_smith\\will_smith13.png',
#   './dataset/cropped/will_smith\\will_smith14.png',
#   './dataset/cropped/will_smith\\will_smith15.png',
#   './dataset/cropped/will_smith\\will_smith16.png',
#   './dataset/cropped/will_smith\\will_smith18.png',
#   './dataset/cropped/will_smith\\will_smith19.png',
#   './dataset/cropped/will_smith\\will_smith2.png',
#   './dataset/cropped/will_smith\\will_smith20.png',
#   './dataset/cropped/will_smith\\will_smith21.png',
#   './dataset/cropped/will_smith\\will_smith22.png',
#   './dataset/cropped/will_smith\\will_smith23.png',
#   './dataset/cropped/will_smith\\will_smith24.png',
#   './dataset/cropped/will_smith\\will_smith25.png',
#   './dataset/cropped/will_smith\\will_smith26.png',
#   './dataset/cropped/will_smith\\will_smith27.png',
#   './dataset/cropped/will_smith\\will_smith29.png',
#   './dataset/cropped/will_smith\\will_smith3.png',
#   './dataset/cropped/will_smith\\will_smith30.png',
#   './dataset/cropped/will_smith\\will_smith31.png',
#   './dataset/cropped/will_smith\\will_smith32.png',
#   './dataset/cropped/will_smith\\will_smith34.png',
#   './dataset/cropped/will_smith\\will_smith35.png',
#   './dataset/cropped/will_smith\\will_smith36.png',
#   './dataset/cropped/will_smith\\will_smith37.png',
#   './dataset/cropped/will_smith\\will_smith38.png',
#   './dataset/cropped/will_smith\\will_smith39.png',
#   './dataset/cropped/will_smith\\will_smith4.png',
#   './dataset/cropped/will_smith\\will_smith40.png',
#   './dataset/cropped/will_smith\\will_smith42.png',
#   './dataset/cropped/will_smith\\will_smith44.png',
#   './dataset/cropped/will_smith\\will_smith45.png',
#   './dataset/cropped/will_smith\\will_smith46.png',
#   './dataset/cropped/will_smith\\will_smith48.png',
#   './dataset/cropped/will_smith\\will_smith49.png',
#   './dataset/cropped/will_smith\\will_smith5.png',
#   './dataset/cropped/will_smith\\will_smith50.png',
#   './dataset/cropped/will_smith\\will_smith7.png',
#   './dataset/cropped/will_smith\\will_smith8.png',
#   './dataset/cropped/will_smith\\will_smith9.png']}

# %%
class_dict={}
count=0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name]=count
    count = count + 1

class_dict
# Out:
# {'brad_pitt': 0,
#  'chris_hemsworth': 1,
#  'dwayane_johnson': 2,
#  'leonardo_dicaprio': 3,
#  'will_smith': 4}

# %% [markdown]
# ### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X , y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scaled_raw_img = cv2.resize(img,(32,32))
        img_har = w2d(img, 'db1',5)
        scaled_img_har = cv2.resize(im_har,(32,32))
        combined_img = np.vstack((scaled_raw_img.reshape(32*32*3,1),scaled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X)
# Out:
# 187

# %%
len(X[0])
# Out:
# 4096

# %%
X[0]
# Out:
# array([[ 61],
#        [ 87],
#        [117],
#        ...,
#        [247],
#        [ 28],
#        [251]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
type(X)
X
# Out:
# [array([[ 61],
#         [ 87],
#         [117],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 47],
#         [ 78],
#         [102],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[101],
#         [134],
#         [159],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 42],
#         [ 87],
#         [112],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 31],
#         [ 41],
#         [ 59],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 74],
#         [ 76],
#         [ 77],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 14],
#         [ 41],
#         [ 68],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[136],
#         [169],
#         [212],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 34],
#         [ 37],
#         [ 49],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 45],
#         [ 57],
#         [ 85],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 44],
#         [ 16],
#         [ 15],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 58],
#         [ 78],
#         [109],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 38],
#         [ 47],
#         [ 61],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[255],
#         [255],
#         [255],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 30],
#         [ 46],
#         [ 59],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[247],
#         [248],
#         [244],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 87],
#         [ 79],
#         [ 79],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[102],
#         [ 83],
#         [ 76],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 10],
#         [ 18],
#         [ 38],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 38],
#         [ 50],
#         [ 74],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[112],
#         [137],
#         [161],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 38],
#         [ 77],
#         [122],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[208],
#         [208],
#         [202],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[223],
#         [217],
#         [213],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 29],
#         [ 44],
#         [ 55],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[  9],
#         [ 54],
#         [ 27],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 78],
#         [ 81],
#         [ 94],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[252],
#         [219],
#         [214],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 14],
#         [ 37],
#         [ 63],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 26],
#         [ 42],
#         [ 65],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 34],
#         [ 52],
#         [ 78],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[116],
#         [113],
#         [135],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 59],
#         [ 56],
#         [ 64],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[233],
#         [237],
#         [248],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 53],
#         [ 67],
#         [ 87],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 31],
#         [ 36],
#         [ 56],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 21],
#         [ 24],
#         [ 32],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 58],
#         [ 94],
#         [130],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 46],
#         [ 37],
#         [ 33],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 62],
#         [114],
#         [150],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[231],
#         [229],
#         [229],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[  0],
#         [  0],
#         [  0],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 30],
#         [ 39],
#         [ 42],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 26],
#         [ 30],
#         [ 44],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[172],
#         [200],
#         [218],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[157],
#         [187],
#         [209],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[  4],
#         [ 45],
#         [ 40],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[140],
#         [133],
#         [130],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 26],
#         [ 54],
#         [ 89],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 15],
#         [ 21],
#         [ 23],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 51],
#         [ 49],
#         [ 49],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 24],
#         [ 39],
#         [ 56],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 39],
#         [ 39],
#         [ 45],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[214],
#         [221],
#         [223],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 17],
#         [ 28],
#         [ 37],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 84],
#         [ 89],
#         [105],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[239],
#         [234],
#         [240],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 17],
#         [ 20],
#         [ 29],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[241],
#         [231],
#         [226],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 50],
#         [ 47],
#         [ 48],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[135],
#         [106],
#         [ 66],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[163],
#         [214],
#         [245],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 35],
#         [ 33],
#         [ 33],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 18],
#         [ 34],
#         [ 57],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 34],
#         [ 42],
#         [ 57],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[133],
#         [106],
#         [ 80],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[  0],
#         [  0],
#         [  0],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 28],
#         [ 27],
#         [ 47],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 25],
#         [ 31],
#         [ 37],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 82],
#         [ 99],
#         [120],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 67],
#         [ 53],
#         [ 57],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 87],
#         [ 87],
#         [ 91],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[255],
#         [255],
#         [255],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 82],
#         [ 70],
#         [ 64],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 14],
#         [ 15],
#         [ 13],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 57],
#         [ 68],
#         [ 96],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 55],
#         [106],
#         [ 89],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 35],
#         [ 27],
#         [ 68],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 55],
#         [ 52],
#         [ 48],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 97],
#         [116],
#         [146],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 81],
#         [ 73],
#         [ 58],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[  4],
#         [  3],
#         [ 12],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 77],
#         [105],
#         [129],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 65],
#         [ 77],
#         [123],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 77],
#         [ 65],
#         [ 59],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[137],
#         [126],
#         [145],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 47],
#         [ 43],
#         [ 19],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 17],
#         [ 28],
#         [ 18],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 67],
#         [ 55],
#         [ 56],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[206],
#         [204],
#         [203],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[112],
#         [159],
#         [182],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[147],
#         [142],
#         [144],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 26],
#         [ 72],
#         [133],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[147],
#         [157],
#         [167],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 81],
#         [189],
#         [237],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 42],
#         [ 74],
#         [150],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[235],
#         [198],
#         [164],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[  5],
#         [ 10],
#         [  9],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[222],
#         [214],
#         [185],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[116],
#         [141],
#         [161],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[  0],
#         [  3],
#         [ 11],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[227],
#         [227],
#         [227],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 69],
#         [ 67],
#         [ 66],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 55],
#         [ 56],
#         [ 72],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[202],
#         [208],
#         [231],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 44],
#         [ 51],
#         [ 60],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 20],
#         [ 20],
#         [ 20],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 14],
#         [ 16],
#         [ 26],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[  4],
#         [  9],
#         [ 10],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 25],
#         [ 45],
#         [ 63],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 41],
#         [ 38],
#         [ 33],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[117],
#         [132],
#         [171],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[111],
#         [103],
#         [135],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[108],
#         [143],
#         [188],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 25],
#         [ 27],
#         [ 35],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[  7],
#         [  5],
#         [  4],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[165],
#         [201],
#         [195],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 46],
#         [ 55],
#         [ 69],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 87],
#         [167],
#         [133],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[171],
#         [198],
#         [230],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 44],
#         [ 50],
#         [ 60],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 58],
#         [ 69],
#         [ 91],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 17],
#         [ 35],
#         [ 71],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 29],
#         [ 36],
#         [ 55],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[154],
#         [179],
#         [221],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 15],
#         [ 25],
#         [ 42],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[122],
#         [128],
#         [161],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 34],
#         [ 41],
#         [ 66],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[240],
#         [205],
#         [158],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[241],
#         [249],
#         [251],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 88],
#         [102],
#         [121],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[231],
#         [227],
#         [226],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[139],
#         [155],
#         [214],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[  8],
#         [ 18],
#         [ 38],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[100],
#         [121],
#         [111],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[244],
#         [249],
#         [250],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[  2],
#         [  8],
#         [ 23],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[179],
#         [234],
#         [237],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[185],
#         [196],
#         [204],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[184],
#         [233],
#         [254],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[  0],
#         [  1],
#         [  9],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 34],
#         [ 70],
#         [ 93],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[245],
#         [251],
#         [245],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[162],
#         [168],
#         [176],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[  5],
#         [  7],
#         [ 15],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 35],
#         [ 31],
#         [ 34],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[133],
#         [ 71],
#         [ 41],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[238],
#         [238],
#         [238],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[134],
#         [136],
#         [144],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 24],
#         [ 25],
#         [ 35],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 42],
#         [ 46],
#         [ 54],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 36],
#         [ 38],
#         [ 40],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 17],
#         [ 15],
#         [ 12],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 11],
#         [ 10],
#         [ 19],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[197],
#         [131],
#         [103],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 35],
#         [ 39],
#         [ 57],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[120],
#         [100],
#         [105],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[239],
#         [233],
#         [222],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[213],
#         [166],
#         [152],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 17],
#         [ 24],
#         [ 33],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[221],
#         [220],
#         [222],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[155],
#         [155],
#         [179],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[123],
#         [116],
#         [167],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[  7],
#         [  9],
#         [ 10],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 29],
#         [ 28],
#         [ 30],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 29],
#         [ 35],
#         [ 54],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[137],
#         [137],
#         [149],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[239],
#         [233],
#         [222],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 28],
#         [ 28],
#         [ 34],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 17],
#         [ 21],
#         [ 39],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 57],
#         [119],
#         [119],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[209],
#         [215],
#         [222],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 13],
#         [ 16],
#         [ 24],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[156],
#         [157],
#         [157],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[251],
#         [177],
#         [171],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[156],
#         [147],
#         [143],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 30],
#         [ 37],
#         [ 64],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[152],
#         [ 93],
#         [ 34],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 15],
#         [ 21],
#         [ 24],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[248],
#         [237],
#         [250],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[231],
#         [205],
#         [202],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 90],
#         [ 84],
#         [ 89],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[ 82],
#         [ 63],
#         [ 59],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[224],
#         [145],
#         [152],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[116],
#         [118],
#         [139],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[136],
#         [138],
#         [163],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8),
#  array([[249],
#         [237],
#         [233],
#         ...,
#         [247],
#         [ 28],
#         [251]], dtype=uint8)]

# %%
type(np.array(X))
# Out:
# numpy.ndarray

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (187, 4096)

# %%
X
# Out:
# array([[ 61.,  87., 117., ..., 247.,  28., 251.],
#        [ 47.,  78., 102., ..., 247.,  28., 251.],
#        [101., 134., 159., ..., 247.,  28., 251.],
#        ...,
#        [116., 118., 139., ..., 247.,  28., 251.],
#        [136., 138., 163., ..., 247.,  28., 251.],
#        [249., 237., 233., ..., 247.,  28., 251.]])

# %% [markdown]
# ## Data cleaning process is done. Now we are ready to train our model

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()),('svc', SVC(kernel= 'rbf',C= 10))])
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('svc', SVC(C=10))])

# %%
pipe.score(X_test,y_test)
# Out:
# 0.7021276595744681

# %%
len(X_test)
# Out:
# 47

# %%
len(X_train)
# Out:
# 140

# %%
164*0.25
# Out:
# 41.0

# %%
print(classification_report(y_test,pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.80      0.70        10
#            1       0.62      0.71      0.67         7
#            2       0.43      0.43      0.43         7
#            3       0.78      0.64      0.70        11
#            4       1.00      0.83      0.91        12
#
#     accuracy                           0.70        47
#    macro avg       0.69      0.68      0.68        47
# weighted avg       0.73      0.70      0.71        47

# %% [markdown]
# ### Using GridSearchCV

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
            
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
            
        }
    }
}

# %%
import pandas as pd
scores = []
best_estimators = {}
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(),mp['model'])
    clf = GridSearchCV(pipe, mp['params'],cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model' : algo,
        'best_score' : clf.best_score_,
        'best_params' : clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_

df = pd.DataFrame(scores,columns = ['model', 'best_score', 'best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.757143
# 1        random_forest    0.514286
# 2  logistic_regression    0.692857
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.723404255319149

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.5531914893617021

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8297872340425532

# %% [markdown]
# #### Using Logistic Regression for model building and deployment

# %%
best_clf = best_estimators['logistic_regression']  # I will be using this model for deployment

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,best_clf.predict(X_test))
cm
# Out:
# array([[ 9,  0,  1,  0,  0],
#        [ 0,  7,  0,  0,  0],
#        [ 2,  0,  4,  0,  1],
#        [ 1,  1,  1,  8,  0],
#        [ 0,  0,  1,  0, 11]], dtype=int64)

# %%
import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True)
plt.xlabel('predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'brad_pitt': 0,
#  'chris_hemsworth': 1,
#  'dwayane_johnson': 2,
#  'leonardo_dicaprio': 3,
#  'will_smith': 4}

# %%
best_clf
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression',
#                  LogisticRegression(C=1, solver='liblinear'))])

# %% [markdown]
# ### Save the trained model

# %%
! pip install joblib
import joblib

joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\guddu\appdata\local\programs\python\python310\lib\site-packages (1.3.1)
# WARNING: Ignoring invalid distribution -illow (c:\users\guddu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\guddu\appdata\local\programs\python\python310\lib\site-packages)
# ['saved_model.pkl']

# %% [markdown]
# ### Save class dictionary

# %%
import json
with open('class_dictionary.json','w') as f:
    f.write(json.dumps(class_dict))
